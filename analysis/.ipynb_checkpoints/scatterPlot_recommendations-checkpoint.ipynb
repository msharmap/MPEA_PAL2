# %% [markdown]
# ## Writing the file with datapoints available for hardness value

# %%
## Misc functions for data editing
# For HEA dataset
import os
import numpy as np
import pandas as pd
import pymatgen as mg
from pymatgen.core.composition import Composition

new_index = [27, 254]
datafile_path = '/Users/maitreyeesharma/WORKSPACE/PostDoc/EngChem/Space@Hopkins_HEA/dataset/'
unique_alloys_training = pd.read_csv(datafile_path+'curated_MPEA_initial_training_hardness_value.csv')
unique_alloys_test = pd.read_csv(datafile_path+'/first_pass/curated_MPEA_initial_test_harness_value.csv')

unique_alloys_training.loc[len(unique_alloys_training.index)] = unique_alloys_test.loc[new_index[0]]
print(len(unique_alloys_training.index))
unique_alloys_training['Target'][len(unique_alloys_training.index)-1] = 868

unique_alloys_training.loc[len(unique_alloys_training.index)] = unique_alloys_test.loc[new_index[1]]
unique_alloys_training['Target'][len(unique_alloys_training.index)-1] = 627

unique_alloys_test = unique_alloys_test.drop(new_index)

unique_alloys_training.to_csv(datafile_path+'curated_MPEA_initial_training_hardness_value.csv',index=False)
unique_alloys_training.to_csv(datafile_path+'curated_MPEA_initial_test_hardness_value.csv',index=False)
# Out:
# 326

# %%
unique_alloys_training
# Out:
#       Ag     Al    B    C   Ca     Co     Cr     Cu     Fe   Ga  ...     W  \
# 0    0.0  0.077  0.0  0.0  0.0  0.308  0.000  0.000  0.308  0.0  ...  0.00
# 1    0.0  0.143  0.0  0.0  0.0  0.286  0.000  0.000  0.286  0.0  ...  0.00
# 2    0.0  0.200  0.0  0.0  0.0  0.267  0.000  0.000  0.267  0.0  ...  0.00
# 3    0.0  0.250  0.0  0.0  0.0  0.250  0.000  0.000  0.250  0.0  ...  0.00
# 4    0.0  0.000  0.0  0.0  0.0  0.333  0.000  0.000  0.333  0.0  ...  0.00
# ..   ...    ...  ...  ...  ...    ...    ...    ...    ...  ...  ...   ...
# 322  0.0  0.196  0.0  0.0  0.0  0.000  0.196  0.000  0.196  0.0  ...  0.00
# 323  0.0  0.190  0.0  0.0  0.0  0.000  0.190  0.000  0.190  0.0  ...  0.00
# 324  0.0  0.000  0.0  0.0  0.0  0.000  0.250  0.000  0.000  0.0  ...  0.25
# 325  0.0  0.167  0.0  0.0  0.0  0.167  0.167  0.000  0.167  0.0  ...  0.00
# 326  0.0  0.000  0.0  0.0  0.0  0.111  0.000  0.111  0.111  0.0  ...  0.00
#
# ...
